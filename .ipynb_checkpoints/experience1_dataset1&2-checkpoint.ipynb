# %%
import pandas as pd
import numpy as np

from wordcloud import WordCloud
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.models import Model
from keras.layers import Conv1D, Dropout, Dense, Embedding, Flatten, Input, MaxPooling1D
from keras.optimizers import Adam

# %% [markdown]
# <h1>Boite à outils</h1>

# %%
def showWordCloud(textData):
    wordcloud = WordCloud(max_words=100, background_color="white", min_font_size=10).generate(textData)

    plt.figure(figsize=(10,10))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    
def plot_confusion_matrix(cm, classes, cmap=plt.cm.Blues):

    cm = cm.astype("float") / cm.sum(axis=1)

    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation="nearest", cmap=cmap)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    
    plt.xticks(tick_marks, classes, fontsize=20, rotation=45)
    plt.yticks(tick_marks, classes, fontsize=20)

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i,j] > 0.5 else "black"        
        plt.text(j, i, format(cm[i, j], ".2f"), horizontalalignment="center", verticalalignment="center", color=color, fontsize=40)

    plt.ylabel("Correction", fontsize=15)
    plt.xlabel("Prédiction", fontsize=15)

# %%
stopWords = set(stopwords.words("english"))
stopWords.add("NaN")

def cleanText(text):
    forbidden = {",","@",";","/","-",":",".","!","?", "#","\"","(",")","\'","’","‘","–"}
    res = str(text)
    if res != None:
        for elm in forbidden:
            res = res.replace(elm, "")
        res = res.split()
        cleaned = []
        for word in res:
            if not word in stopWords:
                cleaned.append(word)
        res = " ".join(cleaned)
    return res

# %% [markdown]
# <h1>Traitement des données</h1>

# %% [markdown]
# <h2>Dataset n°1</h2>

# %% [markdown]
# <h3>Chargement des données</h3>

# %%
#https://www.kaggle.com/clmentbisaillon/fake-and-real-news-dataset
real_news1 = pd.read_csv("./dataset1/True.csv")
fake_news1 = pd.read_csv("./dataset1/Fake.csv")
real_news1["label"] = 0
fake_news1["label"] = 1

dataframe1 = pd.concat([real_news1, fake_news1])
dataframe1["text"] = dataframe1["title"] + dataframe1["text"] 
del dataframe1["title"]
del dataframe1["subject"]
del dataframe1["date"]

dataframe1["text"] = dataframe1["text"].apply(cleanText)

dataframe1.sample(10)
# Out:
#                                                     text  label
# 20346  OBAMAS GAL PAL Loretta Lynch WONT RECUSE HERSE...      1
# 3274   The Internet Loses It Over RNCs Bizarre Statem...      1
# 16409  Czech election winner Babis meets antiEU party...      0
# 8845   US attorney general closes Clinton email probe...      0
# 13647  US threatens South Sudan action Russia warns U...      0
# 17641  Families fleeing Syrias Raqqa say air strikes ...      0
# 5383   Ellen Pompeo Just Shut A Racist Twitter Troll ...      1
# 7999   Donald Trump LIED About Supporting The Iraq Wa...      1
# 2317   Chuck Schumer RESPONDS To Trump With Tweet Of ...      1
# 17184  China stick supply side structural reform over...      0

# %% [markdown]
# <h3>Visualisation des mots des vraies infos</h3>

# %%
titles1_real = dataframe1["text"][dataframe1["label"] == 0].to_string(index=False)
showWordCloud(titles1_real)

# %% [markdown]
# <h3>Visualisation des mots des fausses infos</h3>

# %%
titles1_fake = dataframe1["text"][dataframe1["label"] == 1].to_string(index=False)
showWordCloud(titles1_fake)

# %% [markdown]
# <h2>Dataset n°2</h2>

# %% [markdown]
# <h3>Chargement des données</h3>

# %%
#https://www.kaggle.com/c/fake-news/data
dataframe2 = pd.read_csv("./dataset2/train.csv")
dataframe2["text"] = dataframe2["title"] + dataframe2["text"]
del dataframe2["id"]
del dataframe2["author"]
del dataframe2["title"]

dataframe2["text"] = dataframe2["text"].apply(cleanText)

dataframe2.sample(10)
# Out:
#                                                     text  label
# 7156   PATRIOT Act At 15 Do You Feel SaferPosted Octo...      1
# 15782  Whiten Your Face By Using One Ingredient Wrink...      1
# 556    Finding His Flock A Rural Writers Book Club Th...      0
# 10876                                                nan      1
# 16056  John Podestas New Global OrderAccuracy Media C...      1
# 4193   Donald Trumps News Session Starts War With Wit...      0
# 10031  Hillary Will Go To Prison Not The Oval Office ...      1
# 16491  Bruce Springsteen Rips Con Man Trump Protest S...      0
# 16861  Argentine Court Reopens Investigation ExPresid...      0
# 10214  The strange case Scottish ambulance found amon...      1

# %% [markdown]
# <h3>Visualisation des mots des vraies infos</h3>

# %%
titles2_real = dataframe2["text"][dataframe2["label"] == 0].to_string(index=False)
showWordCloud(titles2_real)

# %% [markdown]
# <h3>Visualisation des mots des fausses informations</h3>

# %%
titles2_fake = dataframe2["text"][dataframe2["label"] == 1].to_string(index=False)
showWordCloud(titles2_fake)

# %% [markdown]
# <h1>It's machine learning time !</h1>

# %% [markdown]
# <h3>Hyperparamètres</h3>

# %%
max_features = 10000#10000 # taille max du vocab
maxlen = 60 # taille max de séquence #60
test_size = 0.80
learning_rate = 0.001
threshold = 0.95
batch_size = 4096
nb_epochs = 15
kernel_size = 3

# %%
x_train, x_test, y_train, y_test = train_test_split(dataframe1["text"], dataframe1["label"], test_size=test_size, random_state = 42)
print(f"Données d'entrainement : {len(x_train)}")
print(f"Données de test : {len(x_test)}")
# Out:
# Données d'entrainement : 8979
# Données de test : 35919

# %%
# vectorisation naïve en "one-hot"
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(pd.concat([dataframe1["text"], dataframe2["text"]]))

# %%
# vectorisation des données d'entraînement
x_train = tokenizer.texts_to_sequences(x_train)
x_train = pad_sequences(x_train, maxlen=maxlen)

# %%
# vectorisation des données de test
x_test = tokenizer.texts_to_sequences(x_test)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %% [markdown]
# <h2>Modèle de Détection (DCNN)</h2>

# %%
input_layer = Input((maxlen,))
x = Embedding(max_features, output_dim=64, input_length=maxlen, trainable=True)(input_layer)

x = Conv1D(64, kernel_size, padding="same", activation="relu")(x)
x = Dropout(.1)(x)
x = MaxPooling1D()(x)

x = Conv1D(32, kernel_size, padding="same", activation="relu")(x)
x = MaxPooling1D()(x)

x = Conv1D(16, kernel_size, padding="same", activation="relu")(x)
x = MaxPooling1D()(x)

x = Flatten()(x)

output_layer = Dense(1, activation="sigmoid")(x)

model = Model(inputs=[input_layer], outputs=[output_layer])

model.compile(loss="binary_crossentropy", optimizer=Adam(lr=learning_rate), metrics=["accuracy"])
model.summary()
# Out:
# Model: "model_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        (None, 60)                0
# _________________________________________________________________
# embedding_19 (Embedding)     (None, 60, 64)            640000
# _________________________________________________________________
# conv1d_55 (Conv1D)           (None, 60, 64)            12352
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 60, 64)            0
# _________________________________________________________________
# max_pooling1d_55 (MaxPooling (None, 30, 64)            0
# _________________________________________________________________
# conv1d_56 (Conv1D)           (None, 30, 32)            6176
# _________________________________________________________________
# max_pooling1d_56 (MaxPooling (None, 15, 32)            0
# _________________________________________________________________
# conv1d_57 (Conv1D)           (None, 15, 16)            1552
# _________________________________________________________________
# max_pooling1d_57 (MaxPooling (None, 7, 16)             0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 112)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 113
# =================================================================
# Total params: 660,193
# Trainable params: 660,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
progress = model.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epochs) 
""", validation_data=(x_test, y_test)"""
# Out:
# C:\Users\Shadow\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/15
# 8979/8979 [==============================] - 1s 102us/step - loss: 0.6923 - accuracy: 0.5249
# Epoch 2/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.6877 - accuracy: 0.5772
# Epoch 3/15
# 8979/8979 [==============================] - 0s 8us/step - loss: 0.6813 - accuracy: 0.6999
# Epoch 4/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.6711 - accuracy: 0.8470
# Epoch 5/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.6538 - accuracy: 0.9032
# Epoch 6/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.6246 - accuracy: 0.9273
# Epoch 7/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.5780 - accuracy: 0.9354
# Epoch 8/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.5100 - accuracy: 0.9335
# Epoch 9/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.4219 - accuracy: 0.9324
# Epoch 10/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.3230 - accuracy: 0.9365
# Epoch 11/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.2322 - accuracy: 0.9446
# Epoch 12/15
# 8979/8979 [==============================] - 0s 8us/step - loss: 0.1644 - accuracy: 0.9522
# Epoch 13/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.1219 - accuracy: 0.9612
# Epoch 14/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.0920 - accuracy: 0.9692
# Epoch 15/15
# 8979/8979 [==============================] - 0s 9us/step - loss: 0.0674 - accuracy: 0.9777
# ', validation_data=(x_test, y_test)'

# %%
model.save("confirmation.h5")

# %%
figure, ax = plt.subplots(1, 2)
figure.set_size_inches(10,5)

ax[0].plot(progress.history["loss"])

ax[1].plot(progress.history["accuracy"])

plt.show()

# %%
to_predict = dataframe2

X_test = to_predict["text"]
X_test = tokenizer.texts_to_sequences(X_test)
X_test = pad_sequences(X_test, maxlen=maxlen)

Y_test = to_predict["label"]

predictions = model.predict(X_test)
for i, prediction in enumerate(predictions):
    predictions[i] = 1 if prediction > threshold else 0

cm2 = confusion_matrix(Y_test, predictions)
plot_confusion_matrix(cm2, cm_plot_labels)

# %%
to_predict = pd.concat([dataframe2, dataframe1])

X_test = to_predict["text"]
X_test = tokenizer.texts_to_sequences(X_test)
X_test = pad_sequences(X_test, maxlen=maxlen)

Y_test = to_predict["label"]

predictions = model.predict(X_test)
for i, prediction in enumerate(predictions):
    predictions[i] = 1 if prediction > threshold else 0


cm_plot_labels = ["Vraie Info","Fausse Info"]
cm = confusion_matrix(Y_test, np.round(predictions))
plot_confusion_matrix(cm, cm_plot_labels)
